# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.4.0.46-cp38-cp38-macosx_10_13_x86_64.whl (52.4 MB)
#      |████████████████████████████████| 52.4 MB 70 kB/s  eta 0:00:01    |███▏                            | 5.1 MB 577 kB/s eta 0:01:22     |████▎                           | 6.9 MB 160 kB/s eta 0:04:43     |██████▏                         | 10.0 MB 906 kB/s eta 0:00:47     |████████▎                       | 13.5 MB 420 kB/s eta 0:01:33     |███████████                     | 18.2 MB 863 kB/s eta 0:00:40     |███████████▏                    | 18.2 MB 863 kB/s eta 0:00:40     |███████████▉                    | 19.4 MB 215 kB/s eta 0:02:34     |██████████████▍                 | 23.6 MB 912 kB/s eta 0:00:32     |████████████████████▏           | 33.1 MB 1.3 MB/s eta 0:00:15     |████████████████████▍           | 33.3 MB 1.3 MB/s eta 0:00:15     |████████████████████▋           | 33.7 MB 1.3 MB/s eta 0:00:15     |█████████████████████▊          | 35.6 MB 1.3 MB/s eta 0:00:14     |██████████████████████          | 35.9 MB 1.3 MB/s eta 0:00:13     |█████████████████████████████▏  | 47.8 MB 921 kB/s eta 0:00:05     |█████████████████████████████▌  | 48.2 MB 99 kB/s eta 0:00:42
# Requirement already satisfied: numpy>=1.17.3 in /Users/mohit/opt/anaconda3/lib/python3.8/site-packages (from opencv-python) (1.18.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.4.0.46

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
img  = cv2.imread("pikachu.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB )

# %%
img.shape
# Out:
# (1175, 1275)

# %%
# img = img[:,:,[2,1,0]]

# %%
# plt.imshow(img, cmap="viridis" )
plt.imshow(img, cmap="gray" )
plt.show()

# %%
cv2.imshow("Pikachu Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (1175, 1275, 3)

# %%
# resize
new_img = cv2.resize(img, (100,100))

# %%
new_img.shape
# Out:
# (100, 100, 3)

# %%
plt.imshow(new_img)

# %%
new_img_2 = cv2.resize(new_img, (1000,1000))

# %%
plt.imshow(new_img_2)

# %%
new_img_2.shape
# Out:
# (1000, 1000, 3)

# %%
ord('q')
# Out:
# 113

# %%
# cv2.EVENT_MBUTTONDOWN?
